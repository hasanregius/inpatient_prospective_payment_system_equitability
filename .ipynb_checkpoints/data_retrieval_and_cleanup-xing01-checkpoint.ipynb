# %% [markdown]
# ###### Team IPPS
#
# The API information can be accessed through this [link](https://data.cms.gov/Medicare-Inpatient/Inpatient-Prospective-Payment-System-IPPS-Provider/97k6-zzx3)
#
# Objectives (This will expand from just data frame formation to include cleanup by Jessie):
# 1. Execute a successful pull of all of the data using the API provided into JSON
# 2. Transform the JSON format into a data frame

# %% [markdown]
# ### Step 1: Installing sodapy, a python package, in jupyter

# %%
# Installing the package sodapy, important for retrieval using the API's detailed method
import sys
# !{sys.executable} -m pip install sodapy
# Out:
# Collecting sodapy
#   Downloading https://files.pythonhosted.org/packages/45/bb/ca05f9ec808ea57417fccdc3e2810ca4fd08d3f85b656b398b77105fb238/sodapy-1.4.7-py2.py3-none-any.whl
# Collecting future==0.16.0 (from sodapy)
#   Downloading https://files.pythonhosted.org/packages/00/2b/8d082ddfed935f3608cc61140df6dcbf0edea1bc3ab52fb6c29ae3e81e85/future-0.16.0.tar.gz (824kB)
# Requirement already satisfied: requests==2.19.1 in c:\users\luffy4g\anaconda3\lib\site-packages (from sodapy) (2.19.1)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in c:\users\luffy4g\anaconda3\lib\site-packages (from requests==2.19.1->sodapy) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\luffy4g\anaconda3\lib\site-packages (from requests==2.19.1->sodapy) (2018.8.24)
# Requirement already satisfied: urllib3<1.24,>=1.21.1 in c:\users\luffy4g\anaconda3\lib\site-packages (from requests==2.19.1->sodapy) (1.23)
# Requirement already satisfied: idna<2.8,>=2.5 in c:\users\luffy4g\anaconda3\lib\site-packages (from requests==2.19.1->sodapy) (2.7)
# Building wheels for collected packages: future
#   Running setup.py bdist_wheel for future: started
#   Running setup.py bdist_wheel for future: finished with status 'done'
#   Stored in directory: C:\Users\Luffy4G\AppData\Local\pip\Cache\wheels\bf\c9\a3\c538d90ef17cf7823fa51fc701a7a7a910a80f6a405bf15b1a
# Successfully built future
# Installing collected packages: future, sodapy
# Successfully installed future-0.16.0 sodapy-1.4.7
# You are using pip version 10.0.1, however version 18.1 is available.
# You should consider upgrading via the 'python -m pip install --upgrade pip' command.

# %% [markdown]
# ### Step 2: Retrieving the dataset

# %%
import sys

# %%
# The API link
link = "https://data.cms.gov/resource/ehrv-m9r6.json"

# The app token
key = "oBbcgRhXZS4dqtTJVyz6zQujv"

# Code snippet for data retrieval using python, as provided by the API information page
import pandas as pd
from sodapy import Socrata

# Unauthenticated client only works with public data sets. Note 'None'
# in place of application token, and no username or password:
client = Socrata("data.cms.gov", key)

# Example authenticated client (needed for non-public datasets):
# client = Socrata(data.cms.gov,
#                  MyAppToken,
#                  userame="user@example.com",
#                  password="AFakePassword")

# First 2000 results, returned as JSON from API / converted to Python list of
# dictionaries by sodapy.
results = client.get("ehrv-m9r6", limit=163065)

# Convert to pandas DataFrame
results_df = pd.DataFrame.from_records(results)

# Checking the head of the data frame
results_df.head(50)
# Out:
#    average_covered_charges average_medicare_payments  \
# 0                 32963.07                   5777.24
# 1                 15131.85                   5787.57
# 2                 37560.37                   5434.95
# 3                 13998.28                   5417.56
# 4                 31633.27                   5658.33
# 5                 16920.79                   6653.80
# 6                 11977.13                   5834.74
# 7                 35841.09                   8031.12
# 8                 28523.39                   6113.38
# 9                 75233.38                   5541.05
# 10                67327.92                   5461.57
# 11                39607.28                   5356.28
# 12                22862.23                   5374.65
# 13                31110.85                   5366.23
# 14                25411.33                   5282.93
# 15                 9234.51                   5676.55
# 16                15895.85                   5930.11
# 17                19721.16                   6192.54
# 18                10710.88                      4968
# 19                51343.75                      5996
# 20                55219.31                   5710.31
# 21                14948.15                   5550.90
# 22                73846.21                   4987.26
# 23                34805.13                   8401.95
# 24                34803.81                   7768.90
# 25                24474.75                   6799.85
# 26                28571.61                      9133
# 27                 35968.5                    6506.5
# 28                26294.52                   6083.42
# 29                26771.78                   7140.85
# 30                 29967.8                   6978.75
# 31                 27349.4                  11026.33
# 32                59443.83                   8487.44
# 33                24714.66                   7673.21
# 34                   37706                   6590.23
# 35                38149.85                   6048.61
# 36                15931.52                  10000.82
# 37                29718.48                    7551.4
# 38                25259.66                   6605.19
# 39                39165.92                   6051.18
# 40                26776.33                   6907.06
# 41                   24560                   7079.36
# 42                54050.58                    6061.5
# 43                   32998                      7046
# 44                25757.64                      5976
# 45                60608.69                   6941.03
# 46                29774.12                   7768.76
# 47                43823.20                   6291.95
# 48                30470.56                   5811.56
# 49                27734.89                   6051.92
#
#    average_medicare_payments_2                            drg_definition  \
# 0                      4763.73  039 - EXTRACRANIAL PROCEDURES W/O CC/MCC
# 1                      4976.71  039 - EXTRACRANIAL PROCEDURES W/O CC/MCC
# 2                      4453.79  039 - EXTRACRANIAL PROCEDURES W/O CC/MCC
# 3                      4129.16  039 - EXTRACRANIAL PROCEDURES W/O CC/MCC
# 4                      4851.44  039 - EXTRACRANIAL PROCEDURES W/O CC/MCC
# 5                      5374.14  039 - EXTRACRANIAL PROCEDURES W/O CC/MCC
# 6                      4761.41  039 - EXTRACRANIAL PROCEDURES W/O CC/MCC
# 7                       5858.5  039 - EXTRACRANIAL PROCEDURES W/O CC/MCC
# 8                       5228.4  039 - EXTRACRANIAL PROCEDURES W/O CC/MCC
# 9                      4386.94  039 - EXTRACRANIAL PROCEDURES W/O CC/MCC
# 10                     4493.57  039 - EXTRACRANIAL PROCEDURES W/O CC/MCC
# 11                      4408.2  039 - EXTRACRANIAL PROCEDURES W/O CC/MCC
# 12                     4186.02  039 - EXTRACRANIAL PROCEDURES W/O CC/MCC
# 13                     4376.23  039 - EXTRACRANIAL PROCEDURES W/O CC/MCC
# 14                     4383.73  039 - EXTRACRANIAL PROCEDURES W/O CC/MCC
# 15                     4509.11  039 - EXTRACRANIAL PROCEDURES W/O CC/MCC
# 16                     3972.85  039 - EXTRACRANIAL PROCEDURES W/O CC/MCC
# 17                     5179.38  039 - EXTRACRANIAL PROCEDURES W/O CC/MCC
# 18                     3898.88  039 - EXTRACRANIAL PROCEDURES W/O CC/MCC
# 19                     4962.45  039 - EXTRACRANIAL PROCEDURES W/O CC/MCC
# 20                     4471.68  039 - EXTRACRANIAL PROCEDURES W/O CC/MCC
# 21                     4219.90  039 - EXTRACRANIAL PROCEDURES W/O CC/MCC
# 22                     3944.42  039 - EXTRACRANIAL PROCEDURES W/O CC/MCC
# 23                     6413.78  039 - EXTRACRANIAL PROCEDURES W/O CC/MCC
# 24                     6951.45  039 - EXTRACRANIAL PROCEDURES W/O CC/MCC
# 25                     5764.87  039 - EXTRACRANIAL PROCEDURES W/O CC/MCC
# 26                     8008.11  039 - EXTRACRANIAL PROCEDURES W/O CC/MCC
# 27                     5379.83  039 - EXTRACRANIAL PROCEDURES W/O CC/MCC
# 28                     4903.33  039 - EXTRACRANIAL PROCEDURES W/O CC/MCC
# 29                     6133.57  039 - EXTRACRANIAL PROCEDURES W/O CC/MCC
# 30                     5969.55  039 - EXTRACRANIAL PROCEDURES W/O CC/MCC
# 31                     9056.06  039 - EXTRACRANIAL PROCEDURES W/O CC/MCC
# 32                     7422.66  039 - EXTRACRANIAL PROCEDURES W/O CC/MCC
# 33                     6541.92  039 - EXTRACRANIAL PROCEDURES W/O CC/MCC
# 34                        5473  039 - EXTRACRANIAL PROCEDURES W/O CC/MCC
# 35                     4951.90  039 - EXTRACRANIAL PROCEDURES W/O CC/MCC
# 36                     7321.64  039 - EXTRACRANIAL PROCEDURES W/O CC/MCC
# 37                     4846.36  039 - EXTRACRANIAL PROCEDURES W/O CC/MCC
# 38                     5665.41  039 - EXTRACRANIAL PROCEDURES W/O CC/MCC
# 39                     5174.25  039 - EXTRACRANIAL PROCEDURES W/O CC/MCC
# 40                      5854.8  039 - EXTRACRANIAL PROCEDURES W/O CC/MCC
# 41                     5204.54  039 - EXTRACRANIAL PROCEDURES W/O CC/MCC
# 42                     5312.16  039 - EXTRACRANIAL PROCEDURES W/O CC/MCC
# 43                     6264.76  039 - EXTRACRANIAL PROCEDURES W/O CC/MCC
# 44                     3592.85  039 - EXTRACRANIAL PROCEDURES W/O CC/MCC
# 45                     5652.65  039 - EXTRACRANIAL PROCEDURES W/O CC/MCC
# 46                      5674.2  039 - EXTRACRANIAL PROCEDURES W/O CC/MCC
# 47                     4788.12  039 - EXTRACRANIAL PROCEDURES W/O CC/MCC
# 48                     4372.61  039 - EXTRACRANIAL PROCEDURES W/O CC/MCC
# 49                     4837.54  039 - EXTRACRANIAL PROCEDURES W/O CC/MCC
#
#    hospital_referral_region_description    provider_city provider_id  \
# 0                           AL - Dothan           DOTHAN       10001
# 1                       AL - Birmingham             BOAZ       10005
# 2                       AL - Birmingham         FLORENCE       10006
# 3                       AL - Birmingham       BIRMINGHAM       10011
# 4                       AL - Birmingham        ALABASTER       10016
# 5                       AL - Montgomery       MONTGOMERY       10023
# 6                       AL - Birmingham          OPELIKA       10029
# 7                       AL - Birmingham       BIRMINGHAM       10033
# 8                       AL - Huntsville       HUNTSVILLE       10039
# 9                       AL - Birmingham          GADSDEN       10040
# 10                      AL - Birmingham          GADSDEN       10046
# 11                          AL - Dothan           DOTHAN       10055
# 12                      AL - Birmingham       BIRMINGHAM       10056
# 13                      AL - Birmingham         ANNISTON       10078
# 14                          AL - Mobile            FOLEY       10083
# 15                      AL - Huntsville          DECATUR       10085
# 16                          AL - Mobile           MOBILE       10090
# 17                      AL - Tuscaloosa       TUSCALOOSA       10092
# 18                          AL - Mobile         FAIRHOPE       10100
# 19                      AL - Birmingham       BIRMINGHAM       10103
# 20                      AL - Birmingham       BIRMINGHAM       10104
# 21                          AL - Mobile           MOBILE       10113
# 22                      AL - Birmingham       BIRMINGHAM       10139
# 23                       AK - Anchorage        ANCHORAGE       20017
# 24                         AZ - Phoenix          PHOENIX       30002
# 25                          AZ - Tucson           TUCSON       30006
# 26                         AZ - Phoenix       COTTONWOOD       30007
# 27                          AZ - Tucson           TUCSON       30010
# 28                          AZ - Tucson           TUCSON       30011
# 29                         AZ - Phoenix         PRESCOTT       30012
# 30                         AZ - Phoenix             YUMA       30013
# 31                         AZ - Phoenix        FLAGSTAFF       30023
# 32                         AZ - Phoenix          PHOENIX       30024
# 33                         AZ - Phoenix          PHOENIX       30030
# 34                         AZ - Phoenix       SCOTTSDALE       30038
# 35                        AZ - Sun City         SUN CITY       30061
# 36                         AZ - Phoenix         SHOW LOW       30062
# 37                            AZ - Mesa             MESA       30065
# 38                         AZ - Phoenix  LAKE HAVASU CIT       30069
# 39                         AZ - Phoenix       SCOTTSDALE       30087
# 40                         AZ - Phoenix         GLENDALE       30089
# 41                         AZ - Phoenix          PHOENIX       30092
# 42                        AZ - Sun City    SUN CITY WEST       30093
# 43                         AZ - Phoenix         GLENDALE       30094
# 44                          AZ - Tucson           TUCSON       30100
# 45                       NV - Las Vegas    BULLHEAD CITY       30101
# 46                         AZ - Phoenix          PHOENIX       30103
# 47                            AZ - Mesa             MESA       30105
# 48                      AR - Springdale     FAYETTEVILLE       40004
# 49                     AR - Little Rock      LITTLE ROCK       40007
#
#                                   provider_name provider_state  \
# 0              SOUTHEAST ALABAMA MEDICAL CENTER             AL
# 1                 MARSHALL MEDICAL CENTER SOUTH             AL
# 2                ELIZA COFFEE MEMORIAL HOSPITAL             AL
# 3                             ST VINCENT'S EAST             AL
# 4                 SHELBY BAPTIST MEDICAL CENTER             AL
# 5                  BAPTIST MEDICAL CENTER SOUTH             AL
# 6           EAST ALABAMA MEDICAL CENTER AND SNF             AL
# 7                UNIVERSITY OF ALABAMA HOSPITAL             AL
# 8                           HUNTSVILLE HOSPITAL             AL
# 9               GADSDEN REGIONAL MEDICAL CENTER             AL
# 10            RIVERVIEW REGIONAL MEDICAL CENTER             AL
# 11                             FLOWERS HOSPITAL             AL
# 12                      ST VINCENT'S BIRMINGHAM             AL
# 13        NORTHEAST ALABAMA REGIONAL MED CENTER             AL
# 14        SOUTH BALDWIN REGIONAL MEDICAL CENTER             AL
# 15                     DECATUR GENERAL HOSPITAL             AL
# 16                          PROVIDENCE HOSPITAL             AL
# 17                D C H REGIONAL MEDICAL CENTER             AL
# 19       701 PRINCETON AVENUE SOUTHWEST             35211               33
# 20                     800 MONTCLAIR RD             35213               29
# 21            5 MOBILE INFIRMARY CIRCLE             36652               66
# 22  2010 BROOKWOOD MEDICAL CENTER DRIVE             35209               19
# 23                     2801 DEBARR ROAD             99508               23
# 24              1111 EAST MCDOWELL ROAD             85006               11
# 25                 5301 EAST GRANT ROAD             85712               40
# 26                 269 SOUTH CANDY LANE             86326               18
# 27             1601 WEST ST MARY'S ROAD             85745               12
# 28                350 NORTH WILMOT ROAD             85711               42
# 29               1003 WILLOW CREEK ROAD             86301               28
# 30                  2400 SOUTH AVENUE A             85364               20
# 31             1200 NORTH BEAVER STREET             86001               15
# 32                 350 WEST THOMAS ROAD             85013               18
# 33          2000 WEST BETHANY HOME ROAD             85015               42
# 34                7400 EAST OSBORN ROAD             85251               13
# 35     10401 WEST THUNDERBIRD BOULEVARD             85351               62
# 36              2200 SHOW LOW LAKE ROAD             85901               17
# 37              1400 SOUTH  DOBSON ROAD             85202               25
# 38                101 CIVIC CENTER LANE             86403               36
# 39             9003 EAST SHEA BOULEVARD             85260               27
# 40           5555 WEST THUNDERBIRD ROAD             85306               15
# 41              19829 NORTH 27TH AVENUE             85027               11
# 42          14502 WEST MEEKER BOULEVARD             85375               12
# 43              18701 NORTH 67TH AVENUE             85308               13
# 44              4888 NORTH STONE AVENUE             85704               14
# 45               2735 SILVER CREEK ROAD             86442               26
# 46             5777 EAST MAYO BOULEVARD             85054               25
# 47             6750 EAST BAYWOOD AVENUE             85206               64
# 48              3215 N NORTH HILLS BLVD             72703               39
# 49                TWO ST VINCENT CIRCLE             72205               55

# %%
resultsSVPC = results_df[["provider_state","provider_name"]]
resultsSVPC.nunique()
# Out:
# provider_state      51
# provider_name     3201
# dtype: int64

# %%
AK_State = resultsSVPC.loc[resultsSVPC["provider_state"] == "AK"]
AK_State_Sorted = AK_State.sort_values(by=["provider_name"])
AK_State_Sorted = AK_State_Sorted.drop_duplicates(subset="provider_name", keep="last")
AK_State_Sorted
# Out:
#        provider_state                       provider_name
# 131261             AK        ALASKA NATIVE MEDICAL CENTER
# 18856              AK            ALASKA REGIONAL HOSPITAL
# 158158             AK          BARTLETT REGIONAL HOSPITAL
# 155136             AK  CENTRAL PENINSULA GENERAL HOSPITAL
# 115944             AK         FAIRBANKS MEMORIAL HOSPITAL
# 88472              AK      MAT-SU REGIONAL MEDICAL CENTER
# 101921             AK               MT EDGECUMBE HOSPITAL
# 77749              AK    PROVIDENCE ALASKA MEDICAL CENTER
# 124946             AK  YUKON KUSKOKWIM DELTA REG HOSPITAL

# %% [markdown]
# # 1) state vs provider count, we will find each state's total number of providers(hospitals)

# %%
resultsSVPC = results_df[["provider_state","provider_name"]].groupby(["provider_state"])
resultsGB_data = pd.DataFrame(resultsSVPC["provider_name"].nunique())
resultsGB_data.head()
# Out:
#                 provider_name
# provider_state
# AK                          9
# AL                         93
# AR                         45
# AZ                         61
# CA                        295

# %%
resultsGB_data = resultsGB_data.sort_values(by="provider_name", ascending = False)
resultsGB_data.head()
# Out:
#                 provider_name
# provider_state
# TX                        308
# CA                        295
# FL                        166
# NY                        161
# PA                        151

# %%
# resultsSVPC = results_df[["provider_state","provider_name"]]
# resultsSVPC = resultsSVPC.groupby("provider_state")
# resultsSVPC.head()

# %% [markdown]
# # 2) state vs total discharges, we will find how many procedures each state do

# %%
resultsGB = results_df.groupby("provider_state")

# %%
resultsGB

# %%
resultsGB_data = pd.DataFrame(resultsGB["drg_definition"].nunique())

# %%
resultsGB_data
# Out:
#                 drg_definition
# provider_state
# AK                          78
# AL                         100
# AR                         100
# AZ                         100
# CA                         100
# CO                         100
# CT                         100
# DC                         100
# DE                         100
# FL                         100
# GA                         100
# HI                          88
# IA                         100
# ID                          95
# IL                         100
# IN                         100
# KS                         100
# KY                         100
# LA                         100
# MA                         100
# MD                         100
# ME                          99
# MI                         100
# MN                         100
# MO                         100
# MS                         100
# MT                          93
# NC                         100
# ND                          95
# NE                         100
# NH                          99
# NJ                         100
# NM                         100
# NV                         100
# NY                         100
# OH                         100
# OK                         100
# OR                          99
# PA                         100
# RI                         100
# SC                         100
# SD                         100
# TN                         100
# TX                         100
# UT                          98
# VA                         100
# VT                          94
# WA                         100
# WI                         100
# WV                         100
# WY                          87

# %%
resultGB = results_df.groupby(["provider_state","drg_definition"]).size().reset_index(name='counts')
resultGB = pd.DataFrame(resultGB)
resultGB.sort_values(["drg_definition", "counts"], ascending = [True, False])
# Out:
#      provider_state                            drg_definition  counts
# 878              FL  039 - EXTRACRANIAL PROCEDURES W/O CC/MCC      81
# 4246             TX  039 - EXTRACRANIAL PROCEDURES W/O CC/MCC      78
# 378              CA  039 - EXTRACRANIAL PROCEDURES W/O CC/MCC      67
# 1361             IL  039 - EXTRACRANIAL PROCEDURES W/O CC/MCC      52
# 3447             OH  039 - EXTRACRANIAL PROCEDURES W/O CC/MCC      48
# 3347             NY  039 - EXTRACRANIAL PROCEDURES W/O CC/MCC      46
# 3746             PA  039 - EXTRACRANIAL PROCEDURES W/O CC/MCC      44
# 2160             MI  039 - EXTRACRANIAL PROCEDURES W/O CC/MCC      40
# 1461             IN  039 - EXTRACRANIAL PROCEDURES W/O CC/MCC      37
# 4146             TN  039 - EXTRACRANIAL PROCEDURES W/O CC/MCC      32
# 3047             NJ  039 - EXTRACRANIAL PROCEDURES W/O CC/MCC      31
# 2360             MO  039 - EXTRACRANIAL PROCEDURES W/O CC/MCC      30
# 978              GA  039 - EXTRACRANIAL PROCEDURES W/O CC/MCC      29
# 4444             VA  039 - EXTRACRANIAL PROCEDURES W/O CC/MCC      28
# 2653             NC  039 - EXTRACRANIAL PROCEDURES W/O CC/MCC      26
# 1761             LA  039 - EXTRACRANIAL PROCEDURES W/O CC/MCC      25
# 1861             MA  039 - EXTRACRANIAL PROCEDURES W/O CC/MCC      25
# 4738             WI  039 - EXTRACRANIAL PROCEDURES W/O CC/MCC      25
